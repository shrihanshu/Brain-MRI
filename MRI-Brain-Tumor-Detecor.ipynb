# %% [markdown]
# # Finding the MRI brain tumor detection dataset

# %% [markdown]
# Let's find the dataset in this link: https://www.kaggle.com/navoneel/brain-mri-images-for-brain-tumor-detection

# %% [markdown]
# # Import packages

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, ConcatDataset
import glob
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score
import random
import cv2
import sys

# %% [markdown]
# ## Reading the Images

# %%
tumor = []
healthy = []
for f in glob.iglob("/Users/shrihanshumishra/Desktop/BrainTumor/Dataset/yes/*.jpg"):
    img = cv2.imread(f)
    img = cv2.resize(img,(128,128))
    b, g, r = cv2.split(img)
    img = cv2.merge([r,g,b])
    tumor.append(img)

for f in glob.iglob("/Users/shrihanshumishra/Desktop/BrainTumor/Dataset/no/*.jpg"):
    img = cv2.imread(f)
    img = cv2.resize(img,(128,128)) 
    b, g, r = cv2.split(img)
    img = cv2.merge([r,g,b])
    healthy.append(img)

# %%
healthy = np.array(healthy)
tumor = np.array(tumor)
All = np.concatenate((healthy, tumor))

# %%
healthy.shape
# Out:
# (85, 128, 128, 3)

# %%
tumor.shape
# Out:
# (86, 128, 128, 3)

# %%
np.random.choice(10, 5, replace=False)
# Out:
# array([1, 4, 9, 5, 3])

# %% [markdown]
# # Visualizing Brain MRI Images

# %%
def plot_random(healthy, tumor, num=5):
    healthy_imgs = healthy[np.random.choice(healthy.shape[0], num, replace=False)]
    tumor_imgs = tumor[np.random.choice(tumor.shape[0], num, replace=False)]
    
    plt.figure(figsize=(16,9))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.title('healthy')
        plt.imshow(healthy_imgs[i])
        
    plt.figure(figsize=(16,9))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.title('tumor')
        plt.imshow(tumor_imgs[i])

# %%
plot_random(healthy, tumor, num=5)

# %% [markdown]
#  # Create Torch Dataset Class

# %% [markdown]
# ## What is Pytorch's Abstract Dataset Class

# %%
class Dataset(object):
    """An abstract class representing a Dataset.

    All other datasets should subclass it. All subclasses should override
    ``__len__``, that provides the size of the dataset, and ``__getitem__``,
    supporting integer indexing in range from 0 to len(self) exclusive.
    """

    def __getitem__(self, index):
        raise NotImplementedError

    def __len__(self):
        raise NotImplementedError

    def __add__(self, other):
        return ConcatDataset([self, other])

# %% [markdown]
# ## Creating MRI cutom dataset class

# %%
class MRI(Dataset):
    def __init__(self):
        
        tumor = []
        healthy = []
        # cv2 - It reads in BGR format by default
        for f in glob.iglob("/Users/shrihanshumishra/Desktop/BrainTumor/Dataset/yes/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) # I can add this later in the boot-camp for more adventure
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1])) # otherwise the shape will be (h,w,#channels)
            tumor.append(img)

        for f in glob.iglob("/Users/shrihanshumishra/Desktop/BrainTumor/Dataset/no/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) 
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1]))
            healthy.append(img)

        # our images
        tumor = np.array(tumor,dtype=np.float32)
        healthy = np.array(healthy,dtype=np.float32)
        
        # our labels
        tumor_label = np.ones(tumor.shape[0], dtype=np.float32)
        healthy_label = np.zeros(healthy.shape[0], dtype=np.float32)
        
        # Concatenates
        self.images = np.concatenate((tumor, healthy), axis=0)
        self.labels = np.concatenate((tumor_label, healthy_label))
        
    def __len__(self):
        return self.images.shape[0]
    
    def __getitem__(self, index):
        
        sample = {'image': self.images[index], 'label':self.labels[index]}
        
        return sample
    
    def normalize(self):
        self.images = self.images/255.0

# %%
mri_dataset = MRI()
mri_dataset.normalize()

# %% [markdown]
# # Creating a dataloader

# %%
# One way of iterating
names={0:'Heathy', 1:'Tumor'}
dataloader = DataLoader(mri_dataset, shuffle=True)
for i, sample in enumerate(dataloader):
    img = sample['image'].squeeze()
    img = img.reshape((img.shape[1], img.shape[2], img.shape[0]))
    plt.title(names[sample['label'].item()])
    plt.imshow(img)
    plt.show()
    if i == 5:
        break

# %% [markdown]
# # Create a model

# %%
import torch.nn as nn
import torch.nn.functional as F

class CNN(nn.Module):
    def __init__(self):
        super(CNN,self).__init__()
        self.cnn_model = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5),
        nn.Tanh(),
        nn.AvgPool2d(kernel_size=2, stride=5),
        nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5),
        nn.Tanh(),
        nn.AvgPool2d(kernel_size=2, stride=5))
        
        self.fc_model = nn.Sequential(
        nn.Linear(in_features=256, out_features=120),
        nn.Tanh(),
        nn.Linear(in_features=120, out_features=84),
        nn.Tanh(),
        nn.Linear(in_features=84, out_features=1))
        
    def forward(self, x):
        x = self.cnn_model(x)
        x = x.view(x.size(0), -1)
        x = self.fc_model(x)
        x = F.sigmoid(x)
        
        return x

# %%
# device will be 'cuda' if a GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# creating a CPU tensor
cpu_tensor = torch.rand(10).to(device)
# moving same tensor to GPU
gpu_tensor = cpu_tensor.to(device)

print(cpu_tensor, cpu_tensor.dtype, type(cpu_tensor), cpu_tensor.type())
print(gpu_tensor, gpu_tensor.dtype, type(gpu_tensor), gpu_tensor.type())

print(cpu_tensor*gpu_tensor)
# Out:
# tensor([0.7703, 0.9312, 0.0900, 0.7155, 0.6202, 0.9461, 0.0830, 0.0981, 0.5560,
#         0.7537]) torch.float32 <class 'torch.Tensor'> torch.FloatTensor
# tensor([0.7703, 0.9312, 0.0900, 0.7155, 0.6202, 0.9461, 0.0830, 0.0981, 0.5560,
#         0.7537]) torch.float32 <class 'torch.Tensor'> torch.FloatTensor
# tensor([0.5933, 0.8672, 0.0081, 0.5119, 0.3846, 0.8950, 0.0069, 0.0096, 0.3091,
#         0.5680])

# %%
mri_dataset = MRI()
mri_dataset.normalize()

model = CNN()

# %%
dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=False)

# %%
model.eval()
outputs = []
y_true = []
with torch.no_grad():
    for D in dataloader:
        image = D['image']
        label = D['label']

        y_hat = model(image)

        outputs.append(y_hat.cpu().detach().numpy())
        y_true.append(label.cpu().detach().numpy())

# %%
outputs = np.concatenate( outputs, axis=0 ).squeeze()
y_true = np.concatenate( y_true, axis=0 ).squeeze()

# %%
def threshold(scores,threshold=0.50, minimum=0, maximum = 1.0):
    x = np.array(list(scores))
    x[x >= threshold] = maximum
    x[x < threshold] = minimum
    return x

# %%
accuracy_score(y_true, threshold(outputs))
# Out:
# 0.37142857142857144

# %%
# a better confusion matrix
import seaborn as sns

plt.figure(figsize=(16,9))
cm = confusion_matrix(y_true, threshold(outputs))
ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax, annot_kws={"size": 20})

# labels, title and ticks
ax.set_xlabel('Predicted labels', fontsize=20)
ax.set_ylabel('True labels', fontsize=20) 
ax.set_title('Confusion Matrix', fontsize=20)
ax.xaxis.set_ticklabels(['Healthy','Tumor'], fontsize=20)
ax.yaxis.set_ticklabels(['Tumor','Healthy'], fontsize=20)
# Out:
# [Text(0, 0.5, 'Tumor'), Text(0, 1.5, 'Healthy')]

# %%
plt.figure(figsize=(16,9))
plt.plot(outputs)
plt.axvline(x=len(tumor), color='r', linestyle='--')
plt.grid()

# %% [markdown]
# # Train the dumb model

# %%
eta = 0.0001
EPOCH = 400
optimizer = torch.optim.Adam(model.parameters(), lr=eta)
dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=True)
model.train()
# Out:
# CNN(
#   (cnn_model): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#     (1): Tanh()
#     (2): AvgPool2d(kernel_size=2, stride=5, padding=0)
#     (3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#     (4): Tanh()
#     (5): AvgPool2d(kernel_size=2, stride=5, padding=0)
#   )
#   (fc_model): Sequential(
#     (0): Linear(in_features=256, out_features=120, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=120, out_features=84, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=84, out_features=1, bias=True)
#   )
# )

# %%
EPOCH=400
for epoch in range(1, EPOCH):
    losses = []
    for D in dataloader:
        optimizer.zero_grad()
        data = D['image']
        label = D['label']
        y_hat = model(data)
        # define loss function
        error = nn.BCELoss() 
        loss = torch.sum(error(y_hat.squeeze(), label))
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    if (epoch+1) % 10 == 0:
        print('Train Epoch: {}\tLoss: {:.6f}'.format(epoch+1, np.mean(losses)))
# Out:
# Train Epoch: 10	Loss: 0.684603
# Train Epoch: 20	Loss: 0.661346
# Train Epoch: 30	Loss: 0.616268
# Train Epoch: 40	Loss: 0.585315
# Train Epoch: 50	Loss: 0.522300
# Train Epoch: 60	Loss: 0.482003
# Train Epoch: 70	Loss: 0.438792
# Train Epoch: 80	Loss: 0.417941
# Train Epoch: 90	Loss: 0.366149
# Train Epoch: 100	Loss: 0.369539
# Train Epoch: 110	Loss: 0.321203
# Train Epoch: 120	Loss: 0.286656
# Train Epoch: 130	Loss: 0.272392
# Train Epoch: 140	Loss: 0.248632
# Train Epoch: 150	Loss: 0.224759
# Train Epoch: 160	Loss: 0.199254
# Train Epoch: 170	Loss: 0.187590
# Train Epoch: 180	Loss: 0.171116
# Train Epoch: 190	Loss: 0.147300
# Train Epoch: 200	Loss: 0.108716
# Train Epoch: 210	Loss: 0.109571
# Train Epoch: 220	Loss: 0.089593
# Train Epoch: 230	Loss: 0.078555
# Train Epoch: 240	Loss: 0.053028
# Train Epoch: 250	Loss: 0.043403
# Train Epoch: 260	Loss: 0.037523
# Train Epoch: 270	Loss: 0.025498
# Train Epoch: 280	Loss: 0.022814
# Train Epoch: 290	Loss: 0.019652
# Train Epoch: 300	Loss: 0.015111
# Train Epoch: 310	Loss: 0.012405
# Train Epoch: 320	Loss: 0.010205
# Train Epoch: 330	Loss: 0.011158
# Train Epoch: 340	Loss: 0.008538
# Train Epoch: 350	Loss: 0.007298
# Train Epoch: 360	Loss: 0.005883
# Train Epoch: 370	Loss: 0.005873
# Train Epoch: 380	Loss: 0.005350
# Train Epoch: 390	Loss: 0.004508
# Train Epoch: 400	Loss: 0.003792

# %% [markdown]
# # Evaluate a smart model

# %%
model.eval()
dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=False)
outputs=[]
y_true = []
with torch.no_grad():
    for D in dataloader:
        image =  D['image']
        label = D['label']
        
        y_hat = model(image)
        
        outputs.append(y_hat.cpu().detach().numpy())
        y_true.append(label.cpu().detach().numpy())
        
outputs = np.concatenate( outputs, axis=0 )
y_true = np.concatenate( y_true, axis=0 )

# %%
accuracy_score(y_true, threshold(outputs))
# Out:
# 1.0

# %%
cm = confusion_matrix(y_true, threshold(outputs))
plt.figure(figsize=(16,9))

ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['Tumor','Healthy'])
ax.yaxis.set_ticklabels(['Tumor','Healthy'])
# Out:
# [Text(0, 0.5, 'Tumor'), Text(0, 1.5, 'Healthy')]

# %%
plt.figure(figsize=(16,9))
plt.plot(outputs)
plt.axvline(x=len(tumor), color='r', linestyle='--')
plt.grid()

# %% [markdown]
# # Visualising the Feature Maps of the Convolutional Filters

# %%
model
# Out:
# CNN(
#   (cnn_model): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#     (1): Tanh()
#     (2): AvgPool2d(kernel_size=2, stride=5, padding=0)
#     (3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#     (4): Tanh()
#     (5): AvgPool2d(kernel_size=2, stride=5, padding=0)
#   )
#   (fc_model): Sequential(
#     (0): Linear(in_features=256, out_features=120, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=120, out_features=84, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=84, out_features=1, bias=True)
#   )
# )

# %%
no_of_layers = 0
conv_layers = []

# %%
model_children = list(model.children())
model_children
# Out:
# [Sequential(
#    (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#    (1): Tanh()
#    (2): AvgPool2d(kernel_size=2, stride=5, padding=0)
#    (3): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#    (4): Tanh()
#    (5): AvgPool2d(kernel_size=2, stride=5, padding=0)
#  ), Sequential(
#    (0): Linear(in_features=256, out_features=120, bias=True)
#    (1): Tanh()
#    (2): Linear(in_features=120, out_features=84, bias=True)
#    (3): Tanh()
#    (4): Linear(in_features=84, out_features=1, bias=True)
#  )]

# %%
for child in model_children:
    if type(child) == nn.Sequential:
        for layer in child.children():
            if type(layer) == nn.Conv2d:
                no_of_layers += 1
                conv_layers.append(layer)

# %%
conv_layers
# Out:
# [Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1)),
#  Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))]

# %%
img = mri_dataset[100]['image']
plt.imshow(img.reshape(128,128,3))

# %%
img = torch.from_numpy(img).to(device)

# %%
img.shape
# Out:
# torch.Size([3, 128, 128])

# %%
img = img.unsqueeze(0)
img.shape
# Out:
# torch.Size([1, 3, 128, 128])

# %%
results = [conv_layers[0](img)]
for i in range(1, len(conv_layers)):
    results.append(conv_layers[i](results[-1]))
outputs = results

# %%
for num_layer in range(len(outputs)):
    plt.figure(figsize=(50, 10))
    layer_viz = outputs[num_layer].squeeze()
    print("Layer ",num_layer+1)
    for i, f in enumerate(layer_viz):
        plt.subplot(2, 8, i + 1)
        plt.imshow(f.detach().cpu().numpy())
        plt.axis("off")
    plt.show()
    plt.close()
# Out:
# Layer  1
# Layer  2

# %% [markdown]
# # Overfitting?

# %%
# Import train/test split function from sklearn
from sklearn.model_selection import train_test_split

# %%
class MRI(Dataset):
    
    def __init__(self):
        
        # Variables to hold the Training data and Validation data
        self.X_train, self.y_train, self.X_val, self.y_val = None, None, None, None
        
        # A variable to determine if we are interested in retrieving the training OR the validation data
        self.mode = 'train'
        
        tumor = []
        healthy = []
        # cv2 - It reads in BGR format by default
        for f in glob.iglob("/Users/shrihanshumishra/Desktop/BrainTumor/Dataset/yes/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) # I can add this later in the boot-camp for more adventure
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1])) # otherwise the shape will be (h,w,#channels)
            tumor.append(img)

        for f in glob.iglob("/Users/shrihanshumishra/Desktop/BrainTumor/Dataset/no/*.jpg"):
            img = cv2.imread(f)
            img = cv2.resize(img,(128,128)) 
            b, g, r = cv2.split(img)
            img = cv2.merge([r,g,b])
            img = img.reshape((img.shape[2],img.shape[0],img.shape[1]))
            healthy.append(img)

        # our images
        tumor = np.array(tumor,dtype=np.float32)
        healthy = np.array(healthy,dtype=np.float32)
        
        # our labels
        tumor_label = np.ones(tumor.shape[0], dtype=np.float32)
        healthy_label = np.zeros(healthy.shape[0], dtype=np.float32)
        
        # Concatenates
        self.images = np.concatenate((tumor, healthy), axis=0)
        self.labels = np.concatenate((tumor_label, healthy_label))
    
    # Define a function that would separate the data into Training and Validation sets
    def train_val_split(self):
        self.X_train, self.X_val, self.y_train, self.y_val = \
        train_test_split(self.images, self.labels, test_size=0.20, random_state=42)
        
    def __len__(self):
        # Use self.mode to deetrmine whether train or val data is of interest
        if self.mode == 'train':
            return self.X_train.shape[0]
        elif self.mode == 'val':
            return self.X_val.shape[0]
    
    def __getitem__(self, idx):
        # Use self.mode to deetrmine whether train or val data is of interest
        if self.mode== 'train':
            sample = {'image': self.X_train[idx], 'label': self.y_train[idx]}
        
        elif self.mode== 'val':
            sample = {'image': self.X_val[idx], 'label': self.y_val[idx]}
        
        return sample
    
    def normalize(self):
        self.images = self.images/255.0

# %% [markdown]
# # Are we overfitting?

# %%
mri_dataset = MRI()
mri_dataset.normalize()
mri_dataset.train_val_split()

# %%
train_dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=True)
val_dataloader = DataLoader(mri_dataset, batch_size=32, shuffle=False)

# %%
device = torch
model = CNN()

# %%
eta=0.0001
optimizer = torch.optim.Adam(model.parameters(), lr=eta)

# %%
# keep track of epoch losses
epoch_train_loss = []
epoch_val_loss = []

# %%
for epoch in range(1,600):
    train_losses = []
    # train for the current epoch
    model.train()
    mri_dataset.mode = 'train'
    for D in train_dataloader:
        # Train the model
        optimizer.zero_grad()
        data = D['image']
        label = D['label']
        
        y_hat = model(data)
        error = nn.BCELoss()
        loss = torch.sum(error(y_hat.squeeze(), label))
        loss.backward()
        optimizer.step()
        train_losses.append(loss.item())
    
    epoch_train_loss.append(np.mean(train_losses))
    
    # validate for the current epoch
    val_losses = []
    model.eval()
    
    mri_dataset.mode = 'val'
    
    with torch.no_grad():
        for D in val_dataloader:            
            data = D['image']
            label = D['label']
            y_hat = model(data)
            error = nn.BCELoss()
            loss = torch.sum(error(y_hat.squeeze(), label))
            val_losses.append(loss.item())
    
    epoch_val_loss.append(np.mean(val_losses))
    
    if (epoch+1) % 10 == 0:
        print('Train Epoch: {}\tTrain Loss: {:.6f}\tVal Loss: {:.6f}'.format(epoch+1, np.mean(train_losses),np.mean(val_losses)))
# Out:
# Train Epoch: 10	Train Loss: 0.677639	Val Loss: 0.699062
# Train Epoch: 20	Train Loss: 0.656533	Val Loss: 0.683528
# Train Epoch: 30	Train Loss: 0.545469	Val Loss: 0.643870
# Train Epoch: 40	Train Loss: 0.550005	Val Loss: 0.635064
# Train Epoch: 50	Train Loss: 0.510718	Val Loss: 0.622258
# Train Epoch: 60	Train Loss: 0.513379	Val Loss: 0.609552
# Train Epoch: 70	Train Loss: 0.481176	Val Loss: 0.596765
# Train Epoch: 80	Train Loss: 0.511047	Val Loss: 0.582833
# Train Epoch: 90	Train Loss: 0.485900	Val Loss: 0.569719
# Train Epoch: 100	Train Loss: 0.439888	Val Loss: 0.549052
# Train Epoch: 110	Train Loss: 0.465834	Val Loss: 0.529234
# Train Epoch: 120	Train Loss: 0.403945	Val Loss: 0.517015
# Train Epoch: 130	Train Loss: 0.413595	Val Loss: 0.481148
# Train Epoch: 140	Train Loss: 0.408501	Val Loss: 0.464105
# Train Epoch: 150	Train Loss: 0.403378	Val Loss: 0.426892
# Train Epoch: 160	Train Loss: 0.329528	Val Loss: 0.397403
# Train Epoch: 170	Train Loss: 0.308814	Val Loss: 0.375511
# Train Epoch: 180	Train Loss: 0.308880	Val Loss: 0.357090
# Train Epoch: 190	Train Loss: 0.288806	Val Loss: 0.348939
# Train Epoch: 200	Train Loss: 0.239392	Val Loss: 0.352606
# Train Epoch: 210	Train Loss: 0.209809	Val Loss: 0.351266
# Train Epoch: 220	Train Loss: 0.188673	Val Loss: 0.352054
# Train Epoch: 230	Train Loss: 0.202725	Val Loss: 0.358519
# Train Epoch: 240	Train Loss: 0.149554	Val Loss: 0.359562
# Train Epoch: 250	Train Loss: 0.124091	Val Loss: 0.381514
# Train Epoch: 260	Train Loss: 0.127079	Val Loss: 0.400664
# Train Epoch: 270	Train Loss: 0.131869	Val Loss: 0.409667
# Train Epoch: 280	Train Loss: 0.078342	Val Loss: 0.421337
# Train Epoch: 290	Train Loss: 0.085245	Val Loss: 0.449155
# Train Epoch: 300	Train Loss: 0.060582	Val Loss: 0.477465
# Train Epoch: 310	Train Loss: 0.046158	Val Loss: 0.505550
# Train Epoch: 320	Train Loss: 0.050281	Val Loss: 0.552144
# Train Epoch: 330	Train Loss: 0.040655	Val Loss: 0.552684
# Train Epoch: 340	Train Loss: 0.028175	Val Loss: 0.582804
# Train Epoch: 350	Train Loss: 0.022809	Val Loss: 0.591410
# Train Epoch: 360	Train Loss: 0.021724	Val Loss: 0.623671
# Train Epoch: 370	Train Loss: 0.020240	Val Loss: 0.642491
# Train Epoch: 380	Train Loss: 0.017778	Val Loss: 0.653877
# Train Epoch: 390	Train Loss: 0.013019	Val Loss: 0.682685
# Train Epoch: 400	Train Loss: 0.010684	Val Loss: 0.701972
# Train Epoch: 410	Train Loss: 0.010764	Val Loss: 0.727477
# Train Epoch: 420	Train Loss: 0.008354	Val Loss: 0.740842
# Train Epoch: 430	Train Loss: 0.007362	Val Loss: 0.759647
# Train Epoch: 440	Train Loss: 0.008945	Val Loss: 0.753941
# Train Epoch: 450	Train Loss: 0.006348	Val Loss: 0.782985
# Train Epoch: 460	Train Loss: 0.006010	Val Loss: 0.791416
# Train Epoch: 470	Train Loss: 0.005743	Val Loss: 0.811423
# Train Epoch: 480	Train Loss: 0.004150	Val Loss: 0.824789
# Train Epoch: 490	Train Loss: 0.003940	Val Loss: 0.831085
# Train Epoch: 500	Train Loss: 0.003664	Val Loss: 0.844280
# Train Epoch: 510	Train Loss: 0.003599	Val Loss: 0.848390
# Train Epoch: 520	Train Loss: 0.002941	Val Loss: 0.870832
# Train Epoch: 530	Train Loss: 0.003182	Val Loss: 0.877012
# Train Epoch: 540	Train Loss: 0.002692	Val Loss: 0.884838
# Train Epoch: 550	Train Loss: 0.002422	Val Loss: 0.900474
# Train Epoch: 560	Train Loss: 0.002386	Val Loss: 0.897822
# Train Epoch: 570	Train Loss: 0.002054	Val Loss: 0.906762
# Train Epoch: 580	Train Loss: 0.002579	Val Loss: 0.918423
# Train Epoch: 590	Train Loss: 0.001918	Val Loss: 0.924406
# Train Epoch: 600	Train Loss: 0.001774	Val Loss: 0.943460

# %%
plt.figure(figsize=(16,9))
plt.plot(epoch_train_loss, c='b', label='Train loss')
plt.plot(epoch_val_loss, c='r', label = 'Validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Loss', fontsize=20)
# Out:
# Text(0, 0.5, 'Loss')
